# %%
from triangle import detect_start
import cv2
import numpy as np
import matplotlib.pyplot as plt
from course_layer import detect_course_impl

# %%
img = cv2.imread('data/644.jpg')
plt.imshow(cv2.cvtColor(img[0:400,1400:2000], cv2.COLOR_BGR2RGB))

# %%
course = detect_course_impl(img)
plt.imshow(course[0:400,1400:2000], cmap='gray')

# %%
triangle = detect_start(course, 27, 30, visualize=True)
